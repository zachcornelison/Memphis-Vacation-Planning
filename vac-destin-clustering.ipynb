# %% [markdown]
# # Overview
# This project serves as the final capstone project for the IBM Professional Data Science course. As the final part of the course, I have been tasked with formulating a (business) problem that can be solved using machine learning techniques and Foursquare location data. The problem I have chosen to solve is vacation planning when visiting the city of Memphis. By using the Foursquare "explore" feature to get popular venues within a specified radius of a pre-determined location, combined with using the kMeans clustering algorithm, this project will determine the best spots to visit in Memphis for anyone staying in Memphis for 3, 5, or 7 days.

# %% [markdown]
# ## Problem
# As a current resident of Memphis, I have personally experienced the struggle in trying to plan activities when family or friends come to visit. Memphis is such a fun, exciting city that offers many things to do for both residents and tourists. While living here has allowed me to experience many different places around town at my own leisure, deciding what to do when guests visit for a limited amount of time is difficult.
#
# This is where kMeans will come into play. Using this clustering algorithm, I will be able to cluster various venues around town into 3, 5, and 7 different clusters. Each cluster will represent one day, giving a nice itinerary of places to visit for different periods of stay. While this problem and solution is more personal, this problem could be approached from the view of a travel agency or AirBnB host looking to increase their business. I have chosen 3, 5, and 7 as the number of days/clusters for the reason that the guests I have visit usually don't stay for any more than a week. However, one could easily modify the number of clusters to represent any desired duration of stay. Although many websites and apps already offer customized itineraries for many different cities, this project primarily serves to practice with and explore the capabilities of clustering algorithms used in conjunction with location data.

# %% [markdown]
# ## Data
# The data to used in this project will come from the Foursquare location data available through their API. The data will consist of finding top venues around the Peabody Hotel--a popular hotel that many visitors stay at when visiting downtown Memphis. After collecting these venues and storing them in a dataframe, I will use the Python Geocoder install to get the latitude and longitude for each location and add these values to the dataframe. This will then allow me to get the venue category for each spot and begin clustering via kMeans.

# %% [markdown]
# ## Methodology

# %% [markdown]
# ### Imports

# %%
# library to handle data in a vectorized manner
import numpy as np

# library for data analsysis
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# install geopy
# !conda install -c conda-forge geopy --yes
# convert an address into latitude and longitude values
from geopy.geocoders import Nominatim 

 # library to handle url requests made to Foursquare to retrieve data
import requests

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# install Folium, map rendering library
import folium 

print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ### Define Foursquare user credientials and version

# %%
CLIENT_ID = 'YTP01X4D1JAYDFMR1QEBL04OY1TWI0LJRBXACDZKVARDICCU'
CLIENT_SECRET = 'OLPDOI3EVXFTSLQB2XUDT4W0ONHZMEMPMG0R0YKAMYCKGWIL'
VERSION = '20180604'

# %% [markdown]
# ### Peabody Hotel latitude and longitude
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent foursquare_agent, as shown below

# %%
address = '118 S 2nd St, Memphis, TN 38103'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print("The Peabody's latitude and longitude are (",latitude, ",", longitude, ").")
# Out:
# The Peabody's latitude and longitude are ( 35.141794 , -90.052684 ).

# %% [markdown]
# ### Use Foursquare to get nearby venues
# Because I am first going to start by creating only 3 clusters for a 3 day visit, I will create and set a variable LIMIT to be equal to 20. This means Foursquare will only grab to the top 20 venues surrounding the Peabody Hotel.
#
# I will also define and set a variable RADIUS to be equal to 16093.4 (meters), approximately 10 miles. These seems like a reasonable radius to include destinations for a person staying downtown only visiting for 3 days.
#
# As I continue through to 5 and 7 clusters (days visiting), I will expand the radius to include further destinations.

# %%
LIMIT = 20
RADIUS = 16093.4

#Get the url to request from Foursquare
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, RADIUS, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=YTP01X4D1JAYDFMR1QEBL04OY1TWI0LJRBXACDZKVARDICCU&client_secret=OLPDOI3EVXFTSLQB2XUDT4W0ONHZMEMPMG0R0YKAMYCKGWIL&ll=35.141794,-90.052684&v=20180604&radius=16093.4&limit=20'

# %% [markdown]
# ### Send get request and examine json results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5da3a609396de0002c957e39'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Memphis',
#   'headerFullLocation': 'Memphis',
#   'headerLocationGranularity': 'city',
#   'totalResults': 244,
#   'suggestedBounds': {'ne': {'lat': 35.286631144837145,
#     'lng': -89.87589373231495},
#    'sw': {'lat': 34.99695685516285, 'lng': -90.22947426768505}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5612b256498e2a8fc88814fd',
#        'name': "Maciel's Tortas & Tacos",
#        'location': {'address': '45 S Main St',
#         'lat': 35.14400029412407,
#         'lng': -90.05303825325505,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14400029412407,
#           'lng': -90.05303825325505}],
#         'distance': 247,
#         'postalCode': '38103',
#         'cc': 'US',
#         'neighborhood': 'Downtown Memphis',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['45 S Main St',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5612b256498e2a8fc88814fd-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058660f964a520495f22e3',
#        'name': 'Orpheum Theater',
#        'location': {'address': '203 S Main St',
#         'crossStreet': 'at Beale St',
#         'lat': 35.14030061014718,
#         'lng': -90.05542945422016,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14030061014718,
#           'lng': -90.05542945422016}],
#         'distance': 300,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['203 S Main St (at Beale St)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058660f964a520495f22e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b155022f964a520f6af23e3',
#        'name': 'AutoZone Park',
#        'location': {'address': '200 Union Ave',
#         'crossStreet': 'at S 3rd St',
#         'lat': 35.14274838513917,
#         'lng': -90.04988372325897,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14274838513917,
#           'lng': -90.04988372325897}],
#         'distance': 276,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['200 Union Ave (at S 3rd St)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d18c941735',
#          'name': 'Baseball Stadium',
#          'pluralName': 'Baseball Stadiums',
#          'shortName': 'Baseball',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_baseball_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b155022f964a520f6af23e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b12aee7f964a5203b8c23e3',
#        'name': 'The Majestic Grille',
#        'location': {'address': '145 S Main St',
#         'crossStreet': 'btwn Peabody Pl & Gayoso',
#         'lat': 35.141173094499045,
#         'lng': -90.05448900945461,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.141173094499045,
#           'lng': -90.05448900945461}],
#         'distance': 178,
#         'postalCode': '38103',
#         'cc': 'US',
#         'neighborhood': 'Downtown Memphis',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['145 S Main St (btwn Peabody Pl & Gayoso)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b12aee7f964a5203b8c23e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05865ff964a520e35e22e3',
#        'name': 'The Peabody Hotel',
#        'location': {'address': '149 Union Ave',
#         'crossStreet': 'at Second St.',
#         'lat': 35.14247474190117,
#         'lng': -90.05201020471328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14247474190117,
#           'lng': -90.05201020471328}],
#         'distance': 97,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['149 Union Ave (at Second St.)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05865ff964a520e35e22e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b155049f964a52044b023e3',
#        'name': 'FedExForum',
#        'location': {'address': '191 Beale St',
#         'crossStreet': 'at S Third St',
#         'lat': 35.1384889300016,
#         'lng': -90.05113992687386,
#         'distance': 393,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['191 Beale St (at S Third St)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d18b941735',
#          'name': 'Basketball Stadium',
#          'pluralName': 'Basketball Stadiums',
#          'shortName': 'Basketball',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_basketball_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '35035779'}},
#       'referralId': 'e-0-4b155049f964a52044b023e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b244a83f964a520606524e3',
#        'name': 'Havana Mix',
#        'location': {'address': '250 Peabody Pl',
#         'lat': 35.14031170965207,
#         'lng': -90.05107793588456,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14031170965207,
#           'lng': -90.05107793588456}],
#         'distance': 220,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['250 Peabody Pl',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d123951735',
#          'name': 'Smoke Shop',
#          'pluralName': 'Smoke Shops',
#          'shortName': 'Smoke Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b244a83f964a520606524e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4abc31e6f964a520b88620e3',
#        'name': 'Gus’s World Famous Hot & Spicy Fried Chicken',
#        'location': {'address': '310 S Front St',
#         'lat': 35.138300259686915,
#         'lng': -90.0579758103274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.138300259686915,
#           'lng': -90.0579758103274}],
#         'distance': 619,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['310 S Front St',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4abc31e6f964a520b88620e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05865ff964a520035f22e3',
#        'name': 'Blues City Cafe',
#        'location': {'address': '138 Beale St',
#         'crossStreet': 'at 2nd St',
#         'lat': 35.14016910735329,
#         'lng': -90.0534682555467,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14016910735329,
#           'lng': -90.0534682555467}],
#         'distance': 194,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['138 Beale St (at 2nd St)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05865ff964a520035f22e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57e9ca9c498e0f3e63ef4ec4',
#        'name': "Catherine and Mary's",
#        'location': {'address': '272 S Main St',
#         'lat': 35.13877526580852,
#         'lng': -90.05566652113892,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.13877526580852,
#           'lng': -90.05566652113892}],
#         'distance': 432,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['272 S Main St',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57e9ca9c498e0f3e63ef4ec4-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c76a4d73adda14383a70aaf',
#        'name': 'Flight Restaurant and Wine Bar',
#        'location': {'address': '39 S Main St',
#         'crossStreet': 'at Monroe Ave',
#         'lat': 35.14426004351449,
#         'lng': -90.0532968227515,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14426004351449,
#           'lng': -90.0532968227515}],
#         'distance': 280,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['39 S Main St (at Monroe Ave)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c76a4d73adda14383a70aaf-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058660f964a5204c5f22e3',
#        'name': 'National Civil Rights Museum',
#        'location': {'address': '450 Mulberry St',
#         'crossStreet': 'at E Butler Av',
#         'lat': 35.13454609999765,
#         'lng': -90.05755280996542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.13454609999765,
#           'lng': -90.05755280996542}],
#         'distance': 920,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['450 Mulberry St (at E Butler Av)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '73883157'}},
#       'referralId': 'e-0-4b058660f964a5204c5f22e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b09d0b0f964a520201e23e3',
#        'name': 'Flying Fish',
#        'location': {'address': '105 S 2nd St',
#         'crossStreet': 'btwn Barboro Alley & Gayoso Ave',
#         'lat': 35.14206387342347,
#         'lng': -90.05273474441728,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14206387342347,
#           'lng': -90.05273474441728}],
#         'distance': 30,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['105 S 2nd St (btwn Barboro Alley & Gayoso Ave)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b09d0b0f964a520201e23e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b075448f964a5201afc22e3',
#        'name': 'Bardog Tavern',
#        'location': {'address': '73 Monroe Ave',
#         'crossStreet': 'Front',
#         'lat': 35.144411577149434,
#         'lng': -90.05392078214153,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.144411577149434,
#           'lng': -90.05392078214153}],
#         'distance': 312,
#         'postalCode': '38103',
#         'cc': 'US',
#         'neighborhood': 'Downtown Memphis',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['73 Monroe Ave (Front)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b075448f964a5201afc22e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b626a70f964a520b2462ae3',
#        'name': "Mr. Handy's Blues Hall",
#        'location': {'address': '182 Beale St',
#         'lat': 35.139649528298825,
#         'lng': -90.05228563657965,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.139649528298825,
#           'lng': -90.05228563657965}],
#         'distance': 241,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['182 Beale St',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b626a70f964a520b2462ae3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fee3001e4b06418e10479cd',
#        'name': "Aldo's Pizza Pies",
#        'location': {'address': '100 S Main St #101',
#         'crossStreet': 'at Monroe Ave',
#         'lat': 35.14231180402726,
#         'lng': -90.05388143876975,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14231180402726,
#           'lng': -90.05388143876975}],
#         'distance': 123,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['100 S Main St #101 (at Monroe Ave)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fee3001e4b06418e10479cd-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f8de1f7e4b0e77df30fbe61',
#        'name': 'Central BBQ',
#        'location': {'address': '147 E Butler Ave',
#         'crossStreet': 'at St Martin St',
#         'lat': 35.13383433711528,
#         'lng': -90.05718469619751,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.13383433711528,
#           'lng': -90.05718469619751}],
#         'distance': 976,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['147 E Butler Ave (at St Martin St)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f8de1f7e4b0e77df30fbe61-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51b6200a498e2f0a0ffaa5a5',
#        'name': 'Tamp & Tap',
#        'location': {'address': '122 Gayoso Ave',
#         'crossStreet': 'Gayoso Ave & November 6th Alley',
#         'lat': 35.14152488145804,
#         'lng': -90.0531723701162,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14152488145804,
#           'lng': -90.0531723701162}],
#         'distance': 53,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['122 Gayoso Ave (Gayoso Ave & November 6th Alley)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '61613735'}},
#       'referralId': 'e-0-51b6200a498e2f0a0ffaa5a5-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c952d2d58d4b60cbaef2f29',
#        'name': 'Lorraine Motel',
#        'location': {'address': '450 Mulberry St',
#         'crossStreet': 'at E Butler Av',
#         'lat': 35.13412957543743,
#         'lng': -90.05793222863501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.13412957543743,
#           'lng': -90.05793222863501}],
#         'distance': 977,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['450 Mulberry St (at E Butler Av)',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c952d2d58d4b60cbaef2f29-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058661f964a5205a5f22e3',
#        'name': 'Court Square',
#        'location': {'address': '45 North 2nd Street',
#         'lat': 35.146040301671924,
#         'lng': -90.05190593860476,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.146040301671924,
#           'lng': -90.05190593860476}],
#         'distance': 477,
#         'postalCode': '38103',
#         'cc': 'US',
#         'city': 'Memphis',
#         'state': 'TN',
#         'country': 'United States',
#         'formattedAddress': ['45 North 2nd Street',
#          'Memphis, TN 38103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058661f964a5205a5f22e3-19'}]}]}}

# %% [markdown]
# ### Convert relevant parts of json to pandas dataframe

# %% [markdown]
# All the relevant information returned in the json is in the *items* key. I will use the **get_category_type** function from the Foursquare lab to retrieve this information. Then clean and structure the json into a Pandas dataframe.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ### Now filter the resulting dataframe to keep only relevant information needed

# %%
venues = results['response']['groups'][0]['items']
    
df1 = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
df1 = df1.loc[:, filtered_columns]

# filter the category for each row
df1['venue.categories'] = df1.apply(get_category_type, axis=1)

# clean columns
df1.columns = [col.split(".")[-1] for col in df1.columns]

df1.head()
# Out:
#                       name           categories        lat        lng
# 0  Maciel's Tortas & Tacos   Mexican Restaurant  35.144000 -90.053038
# 1          Orpheum Theater              Theater  35.140301 -90.055429
# 2            AutoZone Park     Baseball Stadium  35.142748 -90.049884
# 3      The Majestic Grille  American Restaurant  35.141173 -90.054489
# 4        The Peabody Hotel                Hotel  35.142475 -90.052010

# %% [markdown]
# ### Check how many venues resulted from our search

# %%
print('{} venues were found near the Peabody Hotel'.format(df1.shape[0]))
# Out:
# 20 venues were found near the Peabody Hotel

# %% [markdown]
# ## Visualize results

# %% [markdown]
# The resulting dataframe shows the venues returned from the call to Foursquare, including the venue's name, category, latitude, and longitude from the Peadbody hotel. I can now visualize these locations on a map to see where they are in relation to the Peabody.

# %%
# generate map centred around Peabody
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) 


# add Peabody as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Peabody',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(df1.lat, df1.lng, df1.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Analyze our results

# %%
df1.categories.unique()
# Out:
# array(['Mexican Restaurant', 'Theater', 'Baseball Stadium',
#        'American Restaurant', 'Hotel', 'Basketball Stadium', 'Smoke Shop',
#        'Fried Chicken Joint', 'Bar', 'Italian Restaurant',
#        'Tapas Restaurant', 'Museum', 'Seafood Restaurant', 'Music Venue',
#        'Pizza Place', 'BBQ Joint', 'Café', 'History Museum', 'Park'],
#       dtype=object)

# %% [markdown]
# ## Clustering venues for 3 day visitor

# %% [markdown]
# With a dataframe for each venue with relevant information such as geographical location and venue category, the kMeans algorithm can be run on the data. I will set the number of cluster to be 3, 1 for each day of the visit, that will contain venues to be visited based on the output of the algorithm.

# %%
# set number of clusters
kclusters = 3
# run k-means clustering
kmeans1 = KMeans(n_clusters=kclusters, random_state=0)
# Using fit_predict to cluster the dataset
X = df1[['lat','lng']].values
predictions = kmeans1.fit_predict(X)
# check cluster labels generated for each row in the dataframe
kmeans1.labels_[0:10]
# Out:
# array([0, 1, 0, 1, 0, 1, 1, 2, 1, 1], dtype=int32)

# %% [markdown]
# Add results to original dataframe

# %%
clustered = pd.concat([df1.reset_index(), 
                       pd.DataFrame({'Cluster':predictions})], 
                      axis=1)
clustered.drop('index', axis=1, inplace=True)
conditions = [
    clustered['Cluster'] == 0, 
    clustered['Cluster'] == 1,
    clustered['Cluster'] == 2
    ]
choices = ['Day 1', 'Day 2', 'Day3']
clustered['Vacation Day'] = np.select(conditions, choices, default='black')

# %% [markdown]
# Show resulting dataframe sorted by vacation day

# %%
clustered.sort_values(by=['Cluster'])
# Out:
#                                             name           categories  \
# 0                        Maciel's Tortas & Tacos   Mexican Restaurant
# 15                             Aldo's Pizza Pies          Pizza Place
# 13                                 Bardog Tavern                  Bar
# 12                                   Flying Fish   Seafood Restaurant
# 10                Flight Restaurant and Wine Bar     Tapas Restaurant
# 19                                  Court Square                 Park
# 4                              The Peabody Hotel                Hotel
# 2                                  AutoZone Park     Baseball Stadium
# 6                                     Havana Mix           Smoke Shop
# 8                                Blues City Cafe                  Bar
# 3                            The Majestic Grille  American Restaurant
# 14                        Mr. Handy's Blues Hall          Music Venue
# 1                                Orpheum Theater              Theater
# 17                                    Tamp & Tap                 Café
# 5                                     FedExForum   Basketball Stadium
# 9                           Catherine and Mary's   Italian Restaurant
# 7   Gus’s World Famous Hot & Spicy Fried Chicken  Fried Chicken Joint
# 18                                Lorraine Motel       History Museum
# 11                  National Civil Rights Museum               Museum
# 16                                   Central BBQ            BBQ Joint
#
#           lat        lng  Cluster Vacation Day
# 0   35.144000 -90.053038        0        Day 1
# 15  35.142312 -90.053881        0        Day 1
# 13  35.144412 -90.053921        0        Day 1
# 12  35.142064 -90.052735        0        Day 1
# 10  35.144260 -90.053297        0        Day 1
# 19  35.146040 -90.051906        0        Day 1
# 4   35.142475 -90.052010        0        Day 1
# 2   35.142748 -90.049884        0        Day 1
# 6   35.140312 -90.051078        1        Day 2
# 8   35.140169 -90.053468        1        Day 2
# 3   35.141173 -90.054489        1        Day 2
# 14  35.139650 -90.052286        1        Day 2
# 1   35.140301 -90.055429        1        Day 2
# 17  35.141525 -90.053172        1        Day 2
# 5   35.138489 -90.051140        1        Day 2
# 9   35.138775 -90.055667        1        Day 2
# 7   35.138300 -90.057976        2         Day3
# 18  35.134130 -90.057932        2         Day3
# 11  35.134546 -90.057553        2         Day3
# 16  35.133834 -90.057185        2         Day3

# %%
clustered.Cluster.value_counts()
# Out:
# 1    8
# 0    8
# 2    4
# Name: Cluster, dtype: int64

# %% [markdown]
# Now, let's look at each cluster to see what venues we should see.

# %%
cluster0 = clustered.loc[clustered['Cluster'] == 0]
cluster0
# Out:
#                               name          categories        lat        lng  \
# 0          Maciel's Tortas & Tacos  Mexican Restaurant  35.144000 -90.053038
# 2                    AutoZone Park    Baseball Stadium  35.142748 -90.049884
# 4                The Peabody Hotel               Hotel  35.142475 -90.052010
# 10  Flight Restaurant and Wine Bar    Tapas Restaurant  35.144260 -90.053297
# 12                     Flying Fish  Seafood Restaurant  35.142064 -90.052735
# 13                   Bardog Tavern                 Bar  35.144412 -90.053921
# 15               Aldo's Pizza Pies         Pizza Place  35.142312 -90.053881
# 19                    Court Square                Park  35.146040 -90.051906
#
#     Cluster Vacation Day
# 0         0        Day 1
# 2         0        Day 1
# 4         0        Day 1
# 10        0        Day 1
# 12        0        Day 1
# 13        0        Day 1
# 15        0        Day 1
# 19        0        Day 1

# %%
cluster1 = clustered.loc[clustered['Cluster'] == 1]
cluster1
# Out:
#                       name           categories        lat        lng  \
# 1          Orpheum Theater              Theater  35.140301 -90.055429
# 3      The Majestic Grille  American Restaurant  35.141173 -90.054489
# 5               FedExForum   Basketball Stadium  35.138489 -90.051140
# 6               Havana Mix           Smoke Shop  35.140312 -90.051078
# 8          Blues City Cafe                  Bar  35.140169 -90.053468
# 9     Catherine and Mary's   Italian Restaurant  35.138775 -90.055667
# 14  Mr. Handy's Blues Hall          Music Venue  35.139650 -90.052286
# 17              Tamp & Tap                 Café  35.141525 -90.053172
#
#     Cluster Vacation Day
# 1         1        Day 2
# 3         1        Day 2
# 5         1        Day 2
# 6         1        Day 2
# 8         1        Day 2
# 9         1        Day 2
# 14        1        Day 2
# 17        1        Day 2

# %%
cluster2 = clustered.loc[clustered['Cluster'] == 2]
cluster2
# Out:
#                                             name           categories  \
# 7   Gus’s World Famous Hot & Spicy Fried Chicken  Fried Chicken Joint
# 11                  National Civil Rights Museum               Museum
# 16                                   Central BBQ            BBQ Joint
# 18                                Lorraine Motel       History Museum
#
#           lat        lng  Cluster Vacation Day
# 7   35.138300 -90.057976        2         Day3
# 11  35.134546 -90.057553        2         Day3
# 16  35.133834 -90.057185        2         Day3
# 18  35.134130 -90.057932        2         Day3

# %% [markdown]
# ## Visualize each cluster

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=15)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, cluster, label in zip(clustered.lat, clustered.lng, clustered.Cluster, clustered.categories):
    label = folium.Popup(str(label) + ' -- Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster],
        fill_opacity=0.9).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3-day Clustering Results
# From these clusters, we can see that the first day includes 8 spots to visit, 8 spots the second day, and 4 spots again for the final day.
#
# I will now run re-define some variables and run kMeans again with 5 clusters to represent a 5 day visitation. I will also expand my RADIUS to 15 miles instead of just 10, as well as expanding the number of results(LIMIT) to be returned to 35 venues.

# %%
LIMIT = 35
RADIUS = 24140.2

#Get the url to request from Foursquare
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, RADIUS, LIMIT)
#Send request to Foursquare
results = requests.get(url).json()

venues = results['response']['groups'][0]['items']
    
df2 = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
df2 = df2.loc[:, filtered_columns]

# filter the category for each row
df2['venue.categories'] = df2.apply(get_category_type, axis=1)

# clean columns
df2.columns = [col.split(".")[-1] for col in df2.columns]
df2.head()
# Out:
#                                            name           categories  \
# 0                       Maciel's Tortas & Tacos   Mexican Restaurant
# 1                               Orpheum Theater              Theater
# 2                                 AutoZone Park     Baseball Stadium
# 3  Gus’s World Famous Hot & Spicy Fried Chicken  Fried Chicken Joint
# 4                                    FedExForum   Basketball Stadium
#
#          lat        lng
# 0  35.144000 -90.053038
# 1  35.140301 -90.055429
# 2  35.142748 -90.049884
# 3  35.138300 -90.057976
# 4  35.138489 -90.051140

# %%
# generate map centred around Peabody
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) 


# add Peabody as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Peabody',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(df2.lat, df2.lng, df2.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# set number of clusters
kclusters = 5
# run k-means clustering
kmeans2 = KMeans(n_clusters=kclusters, random_state=0)
# Using fit_predict to cluster the dataset
X = df2[['lat','lng']].values
predictions = kmeans2.fit_predict(X)
# check cluster labels generated for each row in the dataframe
kmeans2.labels_[0:10]
# Out:
# array([0, 3, 0, 4, 3, 3, 3, 3, 4, 3], dtype=int32)

# %%
clustered = pd.concat([df2.reset_index(), 
                       pd.DataFrame({'Cluster':predictions})], 
                      axis=1)
clustered.drop('index', axis=1, inplace=True)
conditions = [
    clustered['Cluster'] == 0, 
    clustered['Cluster'] == 1,
    clustered['Cluster'] == 2,
    clustered['Cluster'] == 3,
    clustered['Cluster'] == 4
    ]
choices = ['Day 1', 'Day 2', 'Day3', 'Day4', 'Day5']
clustered['Vacation Day'] = np.select(conditions, choices, default='black')
clustered.sort_values(by=['Cluster'])
# Out:
#                                             name               categories  \
# 0                        Maciel's Tortas & Tacos       Mexican Restaurant
# 32                      Rachel's Salon & Day Spa       Salon / Barbershop
# 2                                  AutoZone Park         Baseball Stadium
# 20                                  Court Square                     Park
# 21         Cannon Center For The Performing Arts             Concert Hall
# 14                                 Bardog Tavern                      Bar
# 28                                      McEwen's      American Restaurant
# 11                Flight Restaurant and Wine Bar         Tapas Restaurant
# 22                                   Butler Park                     Park
# 24                                   Loflin Yard  New American Restaurant
# 25                                  Tom Lee Park                     Park
# 30                        Memphis Farmers Market           Farmers Market
# 31                                 The Corkscrew                Wine Shop
# 26                           High Cotton Brewing                  Brewery
# 18                                    Sun Studio                   Museum
# 23                               Texas De Brazil     Brazilian Restaurant
# 27                               Statue of Elvis         Sculpture Garden
# 29                        B.B. King's Blues Club                Jazz Club
# 19                                    Tamp & Tap                     Café
# 17                             Aldo's Pizza Pies              Pizza Place
# 15                        Mr. Handy's Blues Hall              Music Venue
# 13                                   Flying Fish       Seafood Restaurant
# 12                               Blues City Cafe                      Bar
# 9                           Catherine and Mary's       Italian Restaurant
# 7                                     Havana Mix               Smoke Shop
# 6                              The Peabody Hotel                    Hotel
# 5                            The Majestic Grille      American Restaurant
# 4                                     FedExForum       Basketball Stadium
# 1                                Orpheum Theater                  Theater
# 33                                    Handy Park                     Park
# 34                     World Famous Beale Street            Historic Site
# 16                                Lorraine Motel           History Museum
# 10                                   Central BBQ                BBQ Joint
# 8                   National Civil Rights Museum                   Museum
# 3   Gus’s World Famous Hot & Spicy Fried Chicken      Fried Chicken Joint
#
#           lat        lng  Cluster Vacation Day
# 0   35.144000 -90.053038        0        Day 1
# 32  35.145709 -90.052597        0        Day 1
# 2   35.142748 -90.049884        0        Day 1
# 20  35.146040 -90.051906        0        Day 1
# 21  35.150488 -90.051605        0        Day 1
# 14  35.144412 -90.053921        0        Day 1
# 28  35.144030 -90.052621        0        Day 1
# 11  35.144260 -90.053297        0        Day 1
# 22  35.134783 -90.063123        1        Day 2
# 24  35.128128 -90.062124        1        Day 2
# 25  35.136636 -90.062896        1        Day 2
# 30  35.132194 -90.060189        1        Day 2
# 31  35.133556 -90.061127        1        Day 2
# 26  35.141096 -90.041080        2         Day3
# 18  35.139168 -90.037730        2         Day3
# 23  35.141767 -90.052866        3         Day4
# 27  35.139979 -90.054274        3         Day4
# 29  35.139934 -90.053434        3         Day4
# 19  35.141525 -90.053172        3         Day4
# 17  35.142312 -90.053881        3         Day4
# 15  35.139650 -90.052286        3         Day4
# 13  35.142064 -90.052735        3         Day4
# 12  35.140169 -90.053468        3         Day4
# 9   35.138775 -90.055667        3         Day4
# 7   35.140312 -90.051078        3         Day4
# 6   35.142475 -90.052010        3         Day4
# 5   35.141173 -90.054489        3         Day4
# 4   35.138489 -90.051140        3         Day4
# 1   35.140301 -90.055429        3         Day4
# 33  35.139737 -90.051340        3         Day4
# 34  35.139805 -90.052713        3         Day4
# 16  35.134130 -90.057932        4         Day5
# 10  35.133834 -90.057185        4         Day5
# 8   35.134546 -90.057553        4         Day5
# 3   35.138300 -90.057976        4         Day5

# %%
clustered.Cluster.value_counts()
# Out:
# 3    16
# 0     8
# 1     5
# 4     4
# 2     2
# Name: Cluster, dtype: int64

# %%
cluster0 = clustered.loc[clustered['Cluster'] == 0]
cluster0
# Out:
#                                      name           categories        lat  \
# 0                 Maciel's Tortas & Tacos   Mexican Restaurant  35.144000
# 2                           AutoZone Park     Baseball Stadium  35.142748
# 11         Flight Restaurant and Wine Bar     Tapas Restaurant  35.144260
# 14                          Bardog Tavern                  Bar  35.144412
# 20                           Court Square                 Park  35.146040
# 21  Cannon Center For The Performing Arts         Concert Hall  35.150488
# 28                               McEwen's  American Restaurant  35.144030
# 32               Rachel's Salon & Day Spa   Salon / Barbershop  35.145709
#
#           lng  Cluster Vacation Day
# 0  -90.053038        0        Day 1
# 2  -90.049884        0        Day 1
# 11 -90.053297        0        Day 1
# 14 -90.053921        0        Day 1
# 20 -90.051906        0        Day 1
# 21 -90.051605        0        Day 1
# 28 -90.052621        0        Day 1
# 32 -90.052597        0        Day 1

# %%
cluster1 = clustered.loc[clustered['Cluster'] == 1]
cluster1
# Out:
#                       name               categories        lat        lng  \
# 22             Butler Park                     Park  35.134783 -90.063123
# 24             Loflin Yard  New American Restaurant  35.128128 -90.062124
# 25            Tom Lee Park                     Park  35.136636 -90.062896
# 30  Memphis Farmers Market           Farmers Market  35.132194 -90.060189
# 31           The Corkscrew                Wine Shop  35.133556 -90.061127
#
#     Cluster Vacation Day
# 22        1        Day 2
# 24        1        Day 2
# 25        1        Day 2
# 30        1        Day 2
# 31        1        Day 2

# %%
cluster2 = clustered.loc[clustered['Cluster'] == 2]
cluster2
# Out:
#                    name categories        lat       lng  Cluster Vacation Day
# 18           Sun Studio     Museum  35.139168 -90.03773        2         Day3
# 26  High Cotton Brewing    Brewery  35.141096 -90.04108        2         Day3

# %%
cluster3 = clustered.loc[clustered['Cluster'] == 3]
cluster3
# Out:
#                          name            categories        lat        lng  \
# 1             Orpheum Theater               Theater  35.140301 -90.055429
# 4                  FedExForum    Basketball Stadium  35.138489 -90.051140
# 5         The Majestic Grille   American Restaurant  35.141173 -90.054489
# 6           The Peabody Hotel                 Hotel  35.142475 -90.052010
# 7                  Havana Mix            Smoke Shop  35.140312 -90.051078
# 9        Catherine and Mary's    Italian Restaurant  35.138775 -90.055667
# 12            Blues City Cafe                   Bar  35.140169 -90.053468
# 13                Flying Fish    Seafood Restaurant  35.142064 -90.052735
# 15     Mr. Handy's Blues Hall           Music Venue  35.139650 -90.052286
# 17          Aldo's Pizza Pies           Pizza Place  35.142312 -90.053881
# 19                 Tamp & Tap                  Café  35.141525 -90.053172
# 23            Texas De Brazil  Brazilian Restaurant  35.141767 -90.052866
# 27            Statue of Elvis      Sculpture Garden  35.139979 -90.054274
# 29     B.B. King's Blues Club             Jazz Club  35.139934 -90.053434
# 33                 Handy Park                  Park  35.139737 -90.051340
# 34  World Famous Beale Street         Historic Site  35.139805 -90.052713
#
#     Cluster Vacation Day
# 1         3         Day4
# 4         3         Day4
# 5         3         Day4
# 6         3         Day4
# 7         3         Day4
# 9         3         Day4
# 12        3         Day4
# 13        3         Day4
# 15        3         Day4
# 17        3         Day4
# 19        3         Day4
# 23        3         Day4
# 27        3         Day4
# 29        3         Day4
# 33        3         Day4
# 34        3         Day4

# %%
cluster5 = clustered.loc[clustered['Cluster'] == 4]
cluster5
# Out:
#                                             name           categories  \
# 3   Gus’s World Famous Hot & Spicy Fried Chicken  Fried Chicken Joint
# 8                   National Civil Rights Museum               Museum
# 10                                   Central BBQ            BBQ Joint
# 16                                Lorraine Motel       History Museum
#
#           lat        lng  Cluster Vacation Day
# 3   35.138300 -90.057976        4         Day5
# 8   35.134546 -90.057553        4         Day5
# 10  35.133834 -90.057185        4         Day5
# 16  35.134130 -90.057932        4         Day5

# %% [markdown]
# ## Visualize 5 clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=15)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, cluster, label in zip(clustered.lat, clustered.lng, clustered.Cluster, clustered.categories):
    label = folium.Popup(str(label) + ' -- Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster],
        fill_opacity=0.9).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5-day Clustering Results
# kMeans did not cluster for 5 days as well as I would have liked. The first few clusters are fine, but one of the clusters representing day 3 only returned two venues to explore and day four returned 16 venues. Obviously this is not a very ideal itinerary as we would not want someone to visit 16 spots in one day and only two spots another.
#
# Now I will try again with 5 clusters, extending the radius to 20 miles, but will keep the number of venues to be returned to 35.

# %%
LIMIT = 35
RADIUS = 32186.9

#Get the url to request from Foursquare
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, RADIUS, LIMIT)
#Send request to Foursquare
results = requests.get(url).json()

venues = results['response']['groups'][0]['items']
    
df3 = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
df3 = df3.loc[:, filtered_columns]

# filter the category for each row
df3['venue.categories'] = df3.apply(get_category_type, axis=1)

# clean columns
df3.columns = [col.split(".")[-1] for col in df3.columns]
df3.head()
# Out:
#                                            name           categories  \
# 0                       Maciel's Tortas & Tacos   Mexican Restaurant
# 1                               Orpheum Theater              Theater
# 2  Gus’s World Famous Hot & Spicy Fried Chicken  Fried Chicken Joint
# 3                                 AutoZone Park     Baseball Stadium
# 4                                    FedExForum   Basketball Stadium
#
#          lat        lng
# 0  35.144000 -90.053038
# 1  35.140301 -90.055429
# 2  35.138300 -90.057976
# 3  35.142748 -90.049884
# 4  35.138489 -90.051140

# %%
# generate map centred around Peabody
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14) 


# add Peabody as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Peabody',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(df2.lat, df2.lng, df2.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# set number of clusters
kclusters = 7
# run k-means clustering
kmeans3 = KMeans(n_clusters=kclusters, random_state=0)
# Using fit_predict to cluster the dataset
X = df3[['lat','lng']].values
predictions = kmeans3.fit_predict(X)

#Add results to dataframe
clustered = pd.concat([df3.reset_index(), 
                       pd.DataFrame({'Cluster':predictions})], 
                      axis=1)
clustered.drop('index', axis=1, inplace=True)

conditions = [
    clustered['Cluster'] == 0, 
    clustered['Cluster'] == 1,
    clustered['Cluster'] == 2,
    clustered['Cluster'] == 3,
    clustered['Cluster'] == 4,
    clustered['Cluster'] == 5,
    clustered['Cluster'] == 6
    ]
choices = ['Day 1', 'Day 2', 'Day3', 'Day4', 'Day5', 'Day6', 'Day7']
clustered['Vacation Day'] = np.select(conditions, choices, default='black')
clustered.sort_values(by=['Cluster'])
# Out:
#                                             name               categories  \
# 17                        Mr. Handy's Blues Hall              Music Venue
# 14                               Blues City Cafe                      Bar
# 10                          Catherine and Mary's       Italian Restaurant
# 33                                    Handy Park                     Park
# 8                                     Havana Mix               Smoke Shop
# 6                            The Majestic Grille      American Restaurant
# 27                               Statue of Elvis         Sculpture Garden
# 4                                     FedExForum       Basketball Stadium
# 31                        B.B. King's Blues Club                Jazz Club
# 1                                Orpheum Theater                  Theater
# 29                                 The Corkscrew                Wine Shop
# 24                                  Tom Lee Park                     Park
# 20                                   Butler Park                     Park
# 32                      Rachel's Salon & Day Spa       Salon / Barbershop
# 23         Cannon Center For The Performing Arts             Concert Hall
# 19                                  Court Square                     Park
# 26                               Texas De Brazil     Brazilian Restaurant
# 21                                    Tamp & Tap                     Café
# 30                                      McEwen's      American Restaurant
# 0                        Maciel's Tortas & Tacos       Mexican Restaurant
# 16                                   Flying Fish       Seafood Restaurant
# 15                                 Bardog Tavern                      Bar
# 12                Flight Restaurant and Wine Bar         Tapas Restaurant
# 7                              The Peabody Hotel                    Hotel
# 3                                  AutoZone Park         Baseball Stadium
# 18                             Aldo's Pizza Pies              Pizza Place
# 25                           High Cotton Brewing                  Brewery
# 11                                    Sun Studio                   Museum
# 13                                Lorraine Motel           History Museum
# 9                                    Central BBQ                BBQ Joint
# 28                        Memphis Farmers Market           Farmers Market
# 5                   National Civil Rights Museum                   Museum
# 2   Gus’s World Famous Hot & Spicy Fried Chicken      Fried Chicken Joint
# 34                        Earnestine and Hazel's                 Dive Bar
# 22                                   Loflin Yard  New American Restaurant
#
#           lat        lng  Cluster Vacation Day
# 17  35.139650 -90.052286        0        Day 1
# 14  35.140169 -90.053468        0        Day 1
# 10  35.138775 -90.055667        0        Day 1
# 33  35.139737 -90.051340        0        Day 1
# 8   35.140312 -90.051078        0        Day 1
# 6   35.141173 -90.054489        0        Day 1
# 27  35.139979 -90.054274        0        Day 1
# 4   35.138489 -90.051140        0        Day 1
# 31  35.139934 -90.053434        0        Day 1
# 1   35.140301 -90.055429        0        Day 1
# 29  35.133556 -90.061127        1        Day 2
# 24  35.136636 -90.062896        1        Day 2
# 20  35.134783 -90.063123        1        Day 2
# 32  35.145709 -90.052597        2         Day3
# 23  35.150488 -90.051605        2         Day3
# 19  35.146040 -90.051906        2         Day3
# 26  35.141767 -90.052866        3         Day4
# 21  35.141525 -90.053172        3         Day4
# 30  35.144030 -90.052621        3         Day4
# 0   35.144000 -90.053038        3         Day4
# 16  35.142064 -90.052735        3         Day4
# 15  35.144412 -90.053921        3         Day4
# 12  35.144260 -90.053297        3         Day4
# 7   35.142475 -90.052010        3         Day4
# 3   35.142748 -90.049884        3         Day4
# 18  35.142312 -90.053881        3         Day4
# 25  35.141096 -90.041080        4         Day5
# 11  35.139168 -90.037730        4         Day5
# 13  35.134130 -90.057932        5         Day6
# 9   35.133834 -90.057185        5         Day6
# 28  35.132194 -90.060189        5         Day6
# 5   35.134546 -90.057553        5         Day6
# 2   35.138300 -90.057976        5         Day6
# 34  35.132932 -90.059072        5         Day6
# 22  35.128128 -90.062124        6         Day7

# %%
clustered.Cluster.value_counts()
# Out:
# 3    10
# 0    10
# 5     6
# 2     3
# 1     3
# 4     2
# 6     1
# Name: Cluster, dtype: int64

# %%
cluster0 = clustered.loc[clustered['Cluster'] == 0]
cluster0
# Out:
#                       name           categories        lat        lng  \
# 1          Orpheum Theater              Theater  35.140301 -90.055429
# 4               FedExForum   Basketball Stadium  35.138489 -90.051140
# 6      The Majestic Grille  American Restaurant  35.141173 -90.054489
# 8               Havana Mix           Smoke Shop  35.140312 -90.051078
# 10    Catherine and Mary's   Italian Restaurant  35.138775 -90.055667
# 14         Blues City Cafe                  Bar  35.140169 -90.053468
# 17  Mr. Handy's Blues Hall          Music Venue  35.139650 -90.052286
# 27         Statue of Elvis     Sculpture Garden  35.139979 -90.054274
# 31  B.B. King's Blues Club            Jazz Club  35.139934 -90.053434
# 33              Handy Park                 Park  35.139737 -90.051340
#
#     Cluster Vacation Day
# 1         0        Day 1
# 4         0        Day 1
# 6         0        Day 1
# 8         0        Day 1
# 10        0        Day 1
# 14        0        Day 1
# 17        0        Day 1
# 27        0        Day 1
# 31        0        Day 1
# 33        0        Day 1

# %%
cluster1 = clustered.loc[clustered['Cluster'] == 1]
cluster1
# Out:
#              name categories        lat        lng  Cluster Vacation Day
# 20    Butler Park       Park  35.134783 -90.063123        1        Day 2
# 24   Tom Lee Park       Park  35.136636 -90.062896        1        Day 2
# 29  The Corkscrew  Wine Shop  35.133556 -90.061127        1        Day 2

# %%
cluster2 = clustered.loc[clustered['Cluster'] == 2]
cluster2
# Out:
#                                      name          categories        lat  \
# 19                           Court Square                Park  35.146040
# 23  Cannon Center For The Performing Arts        Concert Hall  35.150488
# 32               Rachel's Salon & Day Spa  Salon / Barbershop  35.145709
#
#           lng  Cluster Vacation Day
# 19 -90.051906        2         Day3
# 23 -90.051605        2         Day3
# 32 -90.052597        2         Day3

# %%
cluster3 = clustered.loc[clustered['Cluster'] == 3]
cluster3
# Out:
#                               name            categories        lat  \
# 0          Maciel's Tortas & Tacos    Mexican Restaurant  35.144000
# 3                    AutoZone Park      Baseball Stadium  35.142748
# 7                The Peabody Hotel                 Hotel  35.142475
# 12  Flight Restaurant and Wine Bar      Tapas Restaurant  35.144260
# 15                   Bardog Tavern                   Bar  35.144412
# 16                     Flying Fish    Seafood Restaurant  35.142064
# 18               Aldo's Pizza Pies           Pizza Place  35.142312
# 21                      Tamp & Tap                  Café  35.141525
# 26                 Texas De Brazil  Brazilian Restaurant  35.141767
# 30                        McEwen's   American Restaurant  35.144030
#
#           lng  Cluster Vacation Day
# 0  -90.053038        3         Day4
# 3  -90.049884        3         Day4
# 7  -90.052010        3         Day4
# 12 -90.053297        3         Day4
# 15 -90.053921        3         Day4
# 16 -90.052735        3         Day4
# 18 -90.053881        3         Day4
# 21 -90.053172        3         Day4
# 26 -90.052866        3         Day4
# 30 -90.052621        3         Day4

# %%
cluster4 = clustered.loc[clustered['Cluster'] == 4]
cluster4
# Out:
#                    name categories        lat       lng  Cluster Vacation Day
# 11           Sun Studio     Museum  35.139168 -90.03773        4         Day5
# 25  High Cotton Brewing    Brewery  35.141096 -90.04108        4         Day5

# %%
cluster5 = clustered.loc[clustered['Cluster'] == 5]
cluster5
# Out:
#                                             name           categories  \
# 2   Gus’s World Famous Hot & Spicy Fried Chicken  Fried Chicken Joint
# 5                   National Civil Rights Museum               Museum
# 9                                    Central BBQ            BBQ Joint
# 13                                Lorraine Motel       History Museum
# 28                        Memphis Farmers Market       Farmers Market
# 34                        Earnestine and Hazel's             Dive Bar
#
#           lat        lng  Cluster Vacation Day
# 2   35.138300 -90.057976        5         Day6
# 5   35.134546 -90.057553        5         Day6
# 9   35.133834 -90.057185        5         Day6
# 13  35.134130 -90.057932        5         Day6
# 28  35.132194 -90.060189        5         Day6
# 34  35.132932 -90.059072        5         Day6

# %%
cluster6 = clustered.loc[clustered['Cluster'] == 6]
cluster6
# Out:
#            name               categories        lat        lng  Cluster  \
# 22  Loflin Yard  New American Restaurant  35.128128 -90.062124        6
#
#    Vacation Day
# 22         Day7

# %% [markdown]
# ## Visualize 7 clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=15)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, cluster, label in zip(clustered.lat, clustered.lng, clustered.Cluster, clustered.categories):
    label = folium.Popup(str(label) + ' -- Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster],
        fill_opacity=0.9).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7-day Clustering Results
# While the kMeans algorithm correctly clustered the 35 venue results into 7 different clusters, the size of the clusters is again a problem when thinking about these clusters realistically. One cluster returned 10 venues to be seen in one day which would be quite a bit, but not impossible. However, two clusters only returned 3 venues, while another only returned 1 venue. The spread of the size of these clusters becomes a problem if these clusters are to be used in real-world vacation planning. A visitor would not like to visit 10 venues in one day and only 1 venue another.

# %% [markdown]
# # Results and Conclusion

# %% [markdown]
# The purpose of this project was to explore how a clustering algorithm such as kMeans could be used on location data. After gathering location data from the Foursquare API, I ran kMeans three different times with three different cluster sizes of 3, 5, and 7 clusters, each representing one day of a visitation to Memphis. While the algorithm clustered fairly for the first run through of only a 3 day visit, it did not perform very well for the 5 and 7 day visits. The spread of size for these clusters would not have been a pragmatic itinerary as nobody would enjoy trying to visit up to 16 venues in one day versus only 1 venue another.
#
# Although the resulting clusters did not turn out to be ideal vacation planners, I still found this project to be a useful exercise in exploring how unsupervised learning, such as the kMeans clustering algorithm, could be used to solve a problem like itinerary creation.
#
# ## Future work
# In future works, the data here could have been added to or refined to include more details about each venue, such as time spent at each spot or time needed to travel from one venue to the other. Seeing as the algorithm only ran based on lat,lng coordinates, the algorithm could have been further improved by clustering based on venue categories. For instance, some of the clusters returned more than 3 restaurants. Unless a visitor had an incredibly large appetite, most people would only be interested in trying out 3 restaurants per day at most. The algorithm used in this project did not account for venue category, but future works could try to solve this issue.
